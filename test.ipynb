# %%
# !pip install seaborn libpysal

# %matplotlib inline

import seaborn as sns
import pandas as pd
import libpysal as ps
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.max_seq_items = 2000
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
path = '/home/levi/Studie/AI_jaar_2/UC/Project/WijkBuurtkaart_2020_v3/buurt_2020_v3.shp'
imd = gpd.read_file(path)

# %%
imd.plot()

imd = imd[imd["GM_NAAM"] == "Amsterdam"]
imd.info()
# imd.head(10)
imd.columns
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 481 entries, 21 to 4641
# Columns: 211 entries, BU_CODE to geometry
# dtypes: float64(101), geometry(1), int64(101), object(8)
# memory usage: 796.7+ KB
# Index(['BU_CODE', 'BU_NAAM', 'WK_CODE', 'GM_CODE', 'GM_NAAM', 'IND_WBI', 'H2O',
#        'POSTCODE', 'DEK_PERC', 'OAD', 'STED', 'BEV_DICHTH', 'AANT_INW',
#        'AANT_MAN', 'AANT_VROUW', 'P_00_14_JR', 'P_15_24_JR', 'P_25_44_JR',
#        'P_45_64_JR', 'P_65_EO_JR', 'P_ONGEHUWD', 'P_GEHUWD', 'P_GESCHEID',
#        'P_VERWEDUW', 'GEBOO_TOT', 'P_GEBOO', 'STERFT_TOT', 'P_STERFT',
#        'AANTAL_HH', 'P_EENP_HH', 'P_HH_Z_K', 'P_HH_M_K', 'GEM_HH_GR',
#        'P_WEST_AL', 'P_N_W_AL', 'P_MAROKKO', 'P_ANT_ARU', 'P_SURINAM',
#        'P_TURKIJE', 'P_OVER_NW', 'A_BED_A', 'A_BED_BF', 'A_BED_GI', 'A_BED_HJ',
#        'A_BED_KL', 'A_BED_MN', 'A_BED_OQ', 'A_BED_RU', 'A_BEDV', 'WONINGEN',
#        'WOZ', 'P_1GEZW', 'P_MGEZW', 'P_BEWNDW', 'P_KOOPWON', 'P_HUURWON',
# ...

# %%
print(imd[~imd["H2O"].isna()].head(10))
print(imd["H2O"].unique())
# Out:
#     WK_CODE WK_NAAM GM_CODE             GM_NAAM   IND_WBI H2O       OAD  \
# 0  WK040099    None  GM0400          Den Helder -99999999  JA -99999999
# 1  WK057599    None  GM0575           Noordwijk -99999999  JA -99999999
# 2  WK031399    None  GM0313          Bunschoten -99999999  JA -99999999
# 3  WK037399    None  GM0373        Bergen (NH.) -99999999  JA -99999999
# 4  WK051899    None  GM0518       's-Gravenhage -99999999  JA -99999999
# 5  WK018499    None  GM0184                 Urk -99999999  JA -99999999
# 6  WK194999    None  GM1949           Waadhoeke -99999999  JA -99999999
# 7  WK065499    None  GM0654             Borsele -99999999  JA -99999999
# 8  WK085199    None  GM0851         Steenbergen -99999999  JA -99999999
# 9  WK167699    None  GM1676  Schouwen-Duiveland -99999999  JA -99999999
#
#        STED  BEV_DICHTH  AANT_INW  ...  P_TURKIJE  P_OVER_NW   OPP_TOT  \
# 0 -99999999   -99999999 -99999999  ...  -99999999  -99999999 -99999999
# ...
